# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['axes.titlesize'] = 15

# %%
url_bank1 = 'https://docs.google.com/spreadsheets/d/17t8Xa8IYHKu2ITComh7CrbDFZm3mvm1pk4VcOnema54/export?&format=csv'
url_bank2 = 'https://docs.google.com/spreadsheets/d/17yS0JJTaQbmwrsIgm71phwoEhQw6hiGfAb5djccP_Fo/export?&format=csv'

df_bank1 = pd.read_csv(url_bank1, decimal=',')
df_bank2 = pd.read_csv(url_bank2, decimal=',')
df_total = pd.concat([df_bank1, df_bank2], ignore_index=True)
display(df_total.head())
# Out:
#          Date Time Version  User          Client Test  Final score
# 0  2023-07-27  NaN    v0.1   NaN             NaN  NaN     0.428571  \
# 1  2023-07-27  NaN    v0.1  iris  test streamlit  NaN     0.487179
# 2  2023-07-27  NaN    v0.1  iris             NaN  NaN     1.000000
# 3  2023-07-27  NaN    v0.1   Job       RiskQuest  NaN     0.259259
# 4  2023-07-27  NaN    v0.1   NaN             NaN  NaN     4.333333
#
#    Internal score  var 1.1  var 1.2  ...  var 5.2 - text var 5.3 - text
# 0             NaN      1.0      1.0  ...             NaN            NaN  \
# 1             NaN      1.0      1.0  ...             NaN            NaN
# 2             NaN      1.0      1.0  ...             NaN            NaN
# 3             NaN      2.0      2.0  ...             NaN            NaN
# 4             NaN      1.0      1.0  ...             NaN            NaN
#
#    tot 5 - text  overwrite 5 - text  var 6.1 - text var 6.2 - text
# ...

# %%
mean_score = df_total['Final score'].mean()
fig, ax = plt.subplots(figsize=(8,6))
ax.hist(df_total['Final score'])
ax.set_xlabel('Circularity Risk Score')
ax.set_ylabel('Count')
ax.set_title('Overview of Circularity Risk Scores')
print(mean_score)
# Out:
# 27.010935838802
